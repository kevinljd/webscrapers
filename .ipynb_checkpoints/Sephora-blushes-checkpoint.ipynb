# %%
# import requests
from bs4 import BeautifulSoup
from selenium import webdriver

index = 1
base_url = 'https://www.sephora.com.au/categories/makeup/face/blush?page='
curr_pg = base_url + str(index)

l = []

# r = requests.get(curr_pg)
# c = r.content
# soup = BeautifulSoup(c, 'html.parser')
for index in range(1,5):
    curr_pg = base_url + str(index)

    browser = webdriver.Chrome('/Users/jiadinhlim/PycharmProjects/EPUP/section_19_realestate_webscrape/practice/chromedriver') #replace with .Firefox(), or with the browser of your choice
    browser.get(curr_pg) #navigate to the page
    innerHTML = browser.execute_script("return document.body.innerHTML")

    soup = BeautifulSoup(innerHTML, 'html.parser')

    all = soup.find_all('div', {'class':'col-6 col-lg-4 product-item'})
    
    if len(all) == 0:
        browser.quit()
        break

    for item in all:
        d = {}
        d['Brand'] = item.find('p', {'class':'product-card-brand'}).text
        d['Product'] = item.find('p', {'class':'product-card-product'}).text
        
        try:
            d['Price'] = item.find('p', {'class':'product-price-old'}).text + ' -> ' + item.find('p', {'class':'product-price-new'}).text + '(' + item.find('p', {'class':'product-price-text'}).text +' off)'
        except:
            d['Price'] = item.find('p', {'class':'product-price'}).text
            
        try:
            d['Stock'] = item.find('div', {'class':'out-of-stock'}).text
        except:
            d['Stock'] = 'In stock'
        l.append(d)
    
browser.quit()

# %%
import pandas

df = pandas.DataFrame(l)
df.to_csv('Sephora-blushes.csv')
df.sort_values('Price').to_csv('Sephora-blushes-Sorted-By-Price.csv')

# %%
df.sort_values('Price')
# Out:
#                  Brand              Price  \
# 1   Sephora Collection   $12.00$6.00(50%)
# 59     Tom Ford Beauty            $123.00
# 5   Sephora Collection             $14.00
# 49            Lanolips             $19.00
# 6   Sephora Collection  $19.00$10.00(50%)
# 11  Sephora Collection  $19.00$14.00(20%)
# 58        Sigma Beauty             $20.00
# 20  Sephora Collection             $21.00
# 67    Make Up For Ever             $25.00
# 25               ZOEVA             $25.00
# 47            Clinique             $25.00
# 72                 3CE             $25.00
# 14               ZOEVA             $26.00
# 36               ZOEVA             $26.00
# 32               ZOEVA             $26.00
# 19               ZOEVA             $26.00
# 18   Benefit Cosmetics             $28.00
# 8    Benefit Cosmetics             $28.00
# 51   Benefit Cosmetics             $28.00
# 17   Benefit Cosmetics             $28.00
# 73               ZOEVA             $29.00
# 64  Sephora Collection  $29.00$20.00(30%)
# 35    Make Up For Ever             $33.00
# 52                 3CE             $34.00
# 3    Benefit Cosmetics             $35.00
# 24            Nudestix             $35.00
# 37                 3CE             $35.00
# 2                ZOEVA             $36.00
# 62          Shu Uemura             $37.00
# 46         Bite Beauty             $37.00
# ..                 ...                ...
# 28   Benefit Cosmetics             $49.00
# 48             Antonym             $49.00
# 21               BECCA             $52.00
# 38   Benefit Cosmetics             $52.00
# 57             Antonym             $53.00
# 29      Natasha Denona             $54.00
# 30      Natasha Denona             $54.00
# 43        Estée Lauder             $55.00
# 7    Benefit Cosmetics             $55.00
# 31   Benefit Cosmetics             $55.00
# 12               BECCA             $55.00
# 45        Estée Lauder             $55.00
# 65  Yves Saint Laurent             $60.00
# 66     Burberry Beauty             $62.00
# 16  Marc Jacobs Beauty             $62.00
# 41  Yves Saint Laurent             $62.00
# 42             Lancôme             $62.00
# 34       Wander Beauty             $63.00
# 33            GUERLAIN             $68.00
# 40      Giorgio Armani             $68.00
# 39            GIVENCHY             $68.00
# 54            GUERLAIN             $71.00
# 53            GUERLAIN             $71.00
# 56     Burberry Beauty             $72.00
# 68         Edward Bess             $72.00
# 60  Yves Saint Laurent             $75.00
# 63  Yves Saint Laurent             $75.00
# 10      DIOR BACKSTAGE             $76.00
# 50               BECCA             $78.00
# 61            GUERLAIN             $88.00
#
#                                               Product         Stock
# 1            Colorful Cheek Ink Gel (Limited Edition)      In stock
# 59                                    Sheer Cheek Duo  Out of Stock
# 5                                    Cheek & Lip Tint      In stock
# 49  Rose Gold 101 Ointment Balm + Tint for Lips an...      In stock
# 6                       Blush To Go (Limited Edition)      In stock
# 11                            Original Colorful Blush      In stock
# 58          Powder Blush - Hot Spot (Limited Edition)  Out of Stock
# 20                                     Colorful Blush      In stock
# 67                                Blush Powder Refill  Out of Stock
# 25               Premiere Highlighter + Blush Palette      In stock
# 47                      CliniqueFIT Lip + Cheek Flush      In stock
# 72                                      Cream Blusher  Out of Stock
# 14                               Aristo Blush Palette      In stock
# 36                             Opulence Blush Palette      In stock
# 32                              Offline Blush Palette      In stock
# 19                     The Basic Moment Blush Palette      In stock
# 18                         Dandelion Finishing Powder      In stock
# 8                             GALifornia Powder Blush      In stock
# 51  Dandelion Box O' Powder Mini Stocking Stuffer ...  Out of Stock
# 17                                    Gold Rush Blush      In stock
# 73                        Sweet Glamour Blush Palette  Out of Stock
# 64                              Microsmooth Sculpting  Out of Stock
# 35                  Artist Face Colors Pressed Powder      In stock
# 52                                         Face Blush      In stock
# 3           Get The Pretty Started! (Limited Edition)      In stock
# 24                        Gel Color  Lip + Cheek Balm      In stock
# 37                             3CE Bold Shading Blush      In stock
# 2                                       Blush Palette      In stock
# 62                              Glow On Blush Refill   Out of Stock
# 46                                         Multistick      In stock
# ..                                                ...           ...
# 28                         Dandelion Dew Liquid Blush      In stock
# 48                      Certified Organic Baked Blush      In stock
# 21                                      Mineral Blush      In stock
# 38                                          Rockateur      In stock
# 57               Certified Organic Highlighting Blush  Out of Stock
# 29                                  Blush Duo Palette      In stock
# 30                                  Blush Duo Palette      In stock
# 43           Pure Color Envy Sculpting Blush (Powder)      In stock
# 7                          Benetint Cheek & Lip Stain      In stock
# 31                         Gogotint Cheek & Lip Stain      In stock
# 12          Shimmering Skin Perfector™ Luminous Blush      In stock
# 45                    Pure Color Envy Sculpting Blush      In stock
# 65                   Baby Doll Kiss & Blush Duo Stick  Out of Stock
# 66                                  Lip & Cheek Bloom  Out of Stock
# 16                                          Air Blush      In stock
# 41               Baby Doll Kiss & Blush Lips & Cheeks      In stock
# 42                  Cushion Blush Subtil Powder Blush      In stock
# 34                  On-the-Glow Blush and Illuminator      In stock
# 33                      Rose Aux Joues - Tender Blush      In stock
# 40                                       Armani Blush      In stock
# 39                                       Prisme Blush      In stock
# 54  Rose Aux Joues Rose Neutre Fall 2018 (Limited ...  Out of Stock
# 53  Rose Aux Joues Corail Doux Fall 2018 (Limited ...  Out of Stock
# 56                                         Light Glow  Out of Stock
# 68                          Blush Extraordinaire 5.9g  Out of Stock
# 60        Blush Volupte - Heart Of Light Powder Blush  Out of Stock
# 63                                      Couture Blush  Out of Stock
# 10                                  Glow Face Palette      In stock
# 50           BECCA x Chrissy Teigen Glow Face Palette  Out of Stock
# 61  Meteorites Heart Shape Face Palette (Limited E...  Out of Stock
#
# [74 rows x 4 columns]
